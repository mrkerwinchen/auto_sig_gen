# %%
import pandas as pd
import numpy as np

# %%
species = "human"
gsm4sig_version = 1

# %%
gsm4sig = pd.read_csv(f"{species}_gsm4sig_v{gsm4sig_version}.csv", index_col=0)
gsm4sig["sig_num"] = gsm4sig.groupby("series_id").cumcount()+1
fc_data = pd.read_csv(f"all_{species}_fc.csv", index_col=0, nrows = 2)
gse_trunc = gsm4sig["series_id"].str.split("-").map(lambda x: x[0])

# %%
gsm4sig
# Out:
#                        series_id  \
# 0                      GSE100363
# 1                      GSE100417
# 2            GSE100483-GSE115580
# 3                      GSE100828
# 4                      GSE101342
# ...                          ...
# 4264           GSE90715-GSE90717
# 4265           GSE90715-GSE90717
# 4266  GSE94036-GSE94037-GSE94038
# 4267  GSE94036-GSE94037-GSE94038
# 4268  GSE94036-GSE94037-GSE94038
#
#                                                ctrl_gsm  \
# 0     ['GSM2679560', 'GSM2679562', 'GSM2679564', 'GS...
# 1            ['GSM2680565', 'GSM2680566', 'GSM2680567']
# 2                          ['GSM2684901', 'GSM2684902']
# 3                          ['GSM2694109', 'GSM2694110']
# 4     ['GSM2701546', 'GSM2701547', 'GSM2701548', 'GS...
# ...                                                 ...
# 4264                       ['GSM2411124', 'GSM2411125']
# 4265                       ['GSM2411124', 'GSM2411125']
# 4266         ['GSM2467446', 'GSM2467447', 'GSM2467448']
# 4267         ['GSM2467446', 'GSM2467447', 'GSM2467448']
# 4268         ['GSM2467446', 'GSM2467447', 'GSM2467448']
#
#                                                pert_gsm  extrap_score  sig_num
# 0     ['GSM2679559', 'GSM2679561', 'GSM2679563', 'GS...             0        1
# 1            ['GSM2680568', 'GSM2680569', 'GSM2680570']             0        1
# 2     ['GSM2684905', 'GSM2684906', 'GSM2684908', 'GS...             0        1
# 3                          ['GSM2694111', 'GSM2694112']             0        1
# 4     ['GSM2701549', 'GSM2701550', 'GSM2701551', 'GS...             0        1
# ...                                                 ...           ...      ...
# 4264                       ['GSM2411130', 'GSM2411131']             1        2
# 4265                       ['GSM2411126', 'GSM2411127']             1        3
# 4266         ['GSM2467452', 'GSM2467454', 'GSM2467453']             1        1
# 4267         ['GSM2467449', 'GSM2467450', 'GSM2467451']             1        2
# 4268         ['GSM2467457', 'GSM2467456', 'GSM2467455']             1        3
#
# [4269 rows x 5 columns]

# %%
fc_data
# Out:
#       Identification of differentially expressed circRNA in gallbladder cancer compared with matched normal tissue GSE100363_1  \
# A1BG                                          -2.198815
# A1CF                                          -0.297826
#
#       CRISPR Inversion of CTCF Sites Alters Genome Topology and Enhancer/Promoter Function GSE71275_1  \
# A1BG                                           0.517292
# A1CF                                           0.000000
#
#       mRNA differential expression in LNCaP cells expressing the wild-type androgen receptor (AR-WT) or the ligand-independent AR-V7 splice variant GSE71334_1  \
# A1BG                                           0.208042
# A1CF                                           0.017953
#
#       EHMT1 and EHMT2 inhibition induce fetal hemoglobin expression [RNA-seq] GSE71421_1  \
# A1BG                                           0.167852
# A1CF                                           0.000000
#
#       Prolyl hydroxylation regulates protein degradation, synthesis, and splicing in human induced pluripotent stem cell-derived cardiomyocytes GSE71560_1  \
# A1BG                                           0.340173
# A1CF                                          -0.002414
#
#       FUS KO mRNA sequencing and anti-FUS RNA immunoprecipitation sequencing GSE71812_1  \
# A1BG                                           0.269884
# A1CF                                           0.449925
#
#       GATA3-mediated chromatin reprogramming in breast cancer cells GSE72141_1  \
# A1BG                                           0.628711
# A1CF                                           1.724392
#
#       The Ro60 Autoantigen Binds Endogenous Retroelements and Regulates Inflammatory Gene Expression GSE72420_1  \
# A1BG                                          -0.025441
# A1CF                                           0.421898
#
#       Transcriptome profiles of moderate dysplasia in oral mucosa associated with malignant conversion GSE72627_1  \
# A1BG                                           0.147546
# A1CF                                           0.000000
#
#       Promoter H3K4 methylation reveals the dynamic reinforcement of activation-induced pathways in human CD4 T cells with differential kinetics in naïve and memory cells (RNA-Seq) GSE73213_1  \
# A1BG                                           0.146013
# A1CF                                           0.000000
#
#       ...  \
# A1BG  ...
# A1CF  ...
#
#       Proteasome machinery is instrumental in a common gain-of-function program of the p53 missense mutants in cancer. GSE68248_1  \
# A1BG                                          -0.203359
# A1CF                                           0.087853
#
#       3D Chromosome Regulatory Landscape of Human Pluripotent Cells GSE69647_1  \
# A1BG                                           0.618354
# A1CF                                           2.936280
#
#       RNA sequencing of mechanically strained NHEKs and control NHEKs GSE70084_1  \
# A1BG                                           0.079507
# A1CF                                           0.000000
#
#       Rocaglamide A converts RNA helicase eIF4A into a sequence-specific translational repressor GSE70211_1  \
# A1BG                                          -0.166670
# A1CF                                          -0.296853
#
#       Investigation about Monocytes in metastatic breast cancer patients under chemotherapy +/- Avastin GSE70404_1  \
# A1BG                                           0.435657
# A1CF                                           1.309233
#
#       A network-based strategy for prioritizing hits from chemical screening data by leveraging genetic, epigenetic and transcriptional datasets GSE70810_1  \
# A1BG                                                0.0
# A1CF                                                0.0
#
#       Treatment of prostate cancer cells with S-adenosylmethionine leads to genomewide alterations of transcription profiles GSE71070_1  \
# A1BG                                           0.004989
# A1CF                                           0.287961
#
#       Next Generation Sequencing Facilitates Quantitative Analysis of PBX3 Regulated Transcriptomes GSE71261_1  \
# A1BG                                           0.142134
# A1CF                                          -0.366221
#
#       RNAseq analysis of ESRP regulated splicing events in prostate cancer GSE129540_1  \
# A1BG                                           -0.35214
# A1CF                                            0.00000
#
#       Differential expression of pancreatic cancer  PANC1 cells treated with pilocarpine GSE102880_1
# A1BG                                           1.082046
# A1CF                                           0.000000
#
# [2 rows x 4269 columns]

# %%
extrap_score = pd.DataFrame([np.repeat(-1, len(fc_data.columns))], columns = fc_data.columns, index = ['score'])

# %%
for study in fc_data.columns:
    gse, sig_num = study.split()[-1].split("_")
    try:
        extrap_score.at['score', study] = (gsm4sig.loc[np.isin(gse_trunc, gse) &
                                                       (gsm4sig.sig_num == int(sig_num)), 
                                                       "extrap_score"].item())
    except:
        print(study) #some studies had their sub/super series order flipped, extrap_score manually inputted
# Out:
# Uridylation by TUT4 and TUT7 marks mRNA for degradation [RNA-Seq] GSE59626_1
# Uridylation by TUT4 and TUT7 marks mRNA for degradation [RNA-Seq] GSE59626_1.1
# TRIB3 Promotes C-Myc-Associated Lymphomagenesis through Inhibition of UBE3B-Mediated c-Myc Degradation GSE126258_1
# TRIB3 Promotes C-Myc-Associated Lymphomagenesis through Inhibition of UBE3B-Mediated c-Myc Degradation GSE126258_1.1
# TRIB3 Promotes C-Myc-Associated Lymphomagenesis through Inhibition of UBE3B-Mediated c-Myc Degradation GSE126258_1.2

# %%
extrap_score.loc["score"].value_counts()
# Out:
# 1    2713
# 3    1109
# 0     377
# 2      70
# Name: score, dtype: int64

# %%
extrap_score.to_csv(f"all_{species}_score.csv")
